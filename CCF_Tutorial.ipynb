# %% [markdown]
# # The Common Coordinate Framework and AllenSDK
#
# The Common Coordinate Framework (CCF) can readily be accessed through the AllenSDK and used to analyze arrays of registered data.
#
# ## Installation
# To get started, you can follow [these](https://allensdk.readthedocs.io/en/latest/install.html) instructions to install the AllenSDK:
#
# First install python 3.7
# Then install the AllenSDK using PIP:
#     pip install allensdk
#
# You can now run the AllenSDK in a jupyter notebook or other environment of your choice. Documentation can be found [here](https://allensdk.readthedocs.io/en/latest/).
#
# ## The Mouse Connectivity Cache
#
# The average template volume, annotation volume, and ontology can all be accessed through the Mouse Connectivity Cache. This also provides access to published connectivity data registered to the CCF. First, import the MouseConnectivityCache. Along with this, I will also import numpy and pandas to use for data processing, as well as pyplot for visualization.

# %%
import numpy as np
import pandas as pd
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache
from matplotlib import pyplot as plt

# %%
# %matplotlib notebook

# %% [markdown]
# ### Accessing the CCF from the MouseConnectivityCache
#
# Instantiate the MouseConnectivityCache (mcc). The default resolution is 25 microns, but 10,50, and 100 microns are also valid options. You can also specify a location of a manifest file, which would keep track of all downloaded assets from template and annotation volumes to experimental data. If a manifest file directory is not provided, one will be created in the current working directory.

# %%
mcc = MouseConnectivityCache(resolution=25)

# %% [markdown]
# #### Annotated Volume and Reference Space
# Now you can get the Reference Space (rsp) at that resolution. This automatically downloads the annotated volume at the specified resolution (25 microns).

# %%
rsp = mcc.get_reference_space()

# %% [markdown]
# The annotated volume is a 3D numpy ndarray, with axes correspond to AP,DV, and ML respectively:

# %%
print('Shape of annotated volume:',rsp.annotation.shape)
print('Annotated volume data type:',rsp.annotation.dtype)
# Out:
# Shape of annotated volume: (528, 320, 456)
# Annotated volume data type: uint32

# %% [markdown]
# The rsp provides access to the structure tree from the ontology. Given that there are multiple atlases and associated ontologies, we are only interested in the structures belonging to this annotation. Thus, we remove unassigned structures from the structure tree. This returns a structure graph which is more easily viewed as a pandas DataFrame:

# %%
sg = rsp.remove_unassigned()

# %%
sg = pd.DataFrame(sg)

# %%
sg.head()
# Out:
#   acronym  graph_id  graph_order   id                           name  \
# 0    root         1            0  997                           root
# 1    grey         1            1    8  Basic cell groups and regions
# 2      CH         1            2  567                       Cerebrum
# 3     CTX         1            3  688                Cerebral cortex
# 4   CTXpl         1            4  695                 Cortical plate
#
#          structure_id_path                                  structure_set_ids  \
# 0                    [997]                                        [691663206]
# 1                 [997, 8]  [112905828, 691663206, 12, 184527634, 11290581...
# 2            [997, 8, 567]  [112905828, 691663206, 12, 184527634, 11290581...
# 3       [997, 8, 567, 688]  [112905828, 691663206, 12, 184527634, 11290581...
# 4  [997, 8, 567, 688, 695]  [112905828, 691663206, 12, 184527634, 11290581...
#
#        rgb_triplet
# 0  [255, 255, 255]
# 1  [191, 218, 227]
# 2  [176, 240, 255]
# 3  [176, 255, 184]
# 4  [112, 255, 112]

# %% [markdown]
# The structures' acronyms, names and IDs can all be linked through the structure graph.

# %% [markdown]
# While the rsp can be used to generate sections in the coronal (0), horizontal (1), or sagittal (2) planes:

# %%
orientation = {'coronal':0,'horizontal':1,'sagittal':2} # makes orientation arguments more readible
pos_microns = lambda x:x*25 # get_slice_image function takes positional arguments in microns instead of 25 micron increments

img = rsp.get_slice_image(orientation['coronal'],pos_microns(230))
plt.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The rsp can also generate masks of given structure IDs. The IDs are provided as a list, and by default include all voxels annotated as children of the given structures (direct_only=False). If only the parent level voxels are desired, set direct_only to True.
#
# Here we make a mask of the Cerebral Cortex, which from the structure graph is shown to have the ID 688.

# %%
ctx_mask = rsp.make_structure_mask([688], direct_only=False)

# %%
print('Shape of mask:',ctx_mask.shape)
print('Mask data type:',ctx_mask.dtype)
print('Value of masked voxels:',ctx_mask.max())
# Out:
# Shape of mask: (528, 320, 456)
# Mask data type: uint8
# Value of masked voxels: 1

# %%
plt.imshow(ctx_mask[230,:,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The mask is the same shape as the specified reference space, and voxels in that space that belong to the Cerebral Cortex are labeled 1.

# %% [markdown]
# #### Average Template Volume
# The mcc also provides access to the average template volume, upon which the CCF is constructed. Downloading the template volume puts it in the directory specified by the manifest file when the mcc was instantiated.

# %%
avg_temp, meta = mcc.get_template_volume()

# %%
print('Shape of average template volume:',avg_temp.shape)
print('Template volume data type:',avg_temp.dtype)
print('Max intensity of template volume:',avg_temp.max())
# Out:
# Shape of average template volume: (528, 320, 456)
# Template volume data type: uint16
# Max intensity of template volume: 516

# %%
plt.imshow(avg_temp[230,:,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Analysis Using CCF
#
# After accessing the different components of the CCF, we can now use them for analysis. For example, we can sample voxels from any data array in that space using the masks from rsp. To do this, we can simply get the coordinates of the masked voxels and sample our data array with them.

# %%
ctx_mask.nonzero()
# Out:
# (array([  1,   1,   1, ..., 416, 416, 416], dtype=int64),
#  array([137, 137, 137, ..., 143, 143, 143], dtype=int64),
#  array([198, 199, 200, ..., 383, 384, 385], dtype=int64))

# %%
avg_temp[ctx_mask.nonzero()]
# Out:
# array([ 4,  4,  4, ..., 69, 69, 70], dtype=uint16)

# %% [markdown]
# This resulting array contains the intensity of each voxel in the Cerebral Cortex of the average template volume.

# %% [markdown]
# ### Accessing Experiments
#
# The mcc also allows us to access published experiments. We can view these as a pandas DataFrame and filter out the data of interest. For example, we can look at all experiments listed as having primary injections in VISp.

# %%
exp = mcc.get_experiments(dataframe=True)

# %%
exp[exp.structure_abbrev == 'VISp']
# Out:
#           gender  injection_structures  injection_volume  injection_x  \
# id
# 500836840      M                 [385]          0.375218         8850
# 307297141      M            [385, 409]          0.663636         9230
# 272821309      F                 [385]          0.125424         8690
# 512315551      M  [385, 409, 425, 894]          1.614223         8460
# 510581751      M                 [385]          0.031653         9230
# ...          ...                   ...               ...          ...
# 596571282      M                 [385]          0.001158         9400
# 638978767      F                 [385]          0.006102         8350
# 503069254      M                 [385]          0.071099         8690
# 263780729      M                 [385]          0.223684         8870
# 156545918      M                 [385]          0.031552         9340
#
#            injection_y  injection_z  product_id              specimen_name  \
# id
# 500836840         1440         3550          36       Emx1-IRES-Cre-212542
# 307297141         1910         8430           5             C57BL/6-152922
# 272821309          900         8110           5          Cux2-IRES-Cre-288
# 512315551         1630         2340          36       Emx1-IRES-Cre-234272
# 510581751         1390         3070          36       Tlx3-Cre_PL56-232871
# ...                ...          ...         ...                        ...
# 596571282         1510         8810           5   Oxtr-T2A-Cre;Ai14-318593
# 638978767          590         8160           5  Penk-IRES2-Cre-neo-343079
# 503069254         1440         3090          36      Rbp4-Cre_KL100-227918
# 263780729          860         7920           5          Cux2-IRES-Cre-235
# 156545918         1850         8290           5             Ntsr1-Cre-3502
#
#              strain structure_abbrev  structure_id       structure_name  \
# id
# 500836840      None             VISp           385  Primary visual area
# 307297141  C57BL/6J             VISp           385  Primary visual area
# 272821309  C57BL/6J             VISp           385  Primary visual area
# 512315551      None             VISp           385  Primary visual area
# 510581751      None             VISp           385  Primary visual area
# ...             ...              ...           ...                  ...
# 596571282   unknown             VISp           385  Primary visual area
# 638978767      None             VISp           385  Primary visual area
# 503069254      None             VISp           385  Primary visual area
# 263780729      None             VISp           385  Primary visual area
# 156545918  C57BL/6J             VISp           385  Primary visual area
#
#               transgenic_line  transgenic_line_id         id  \
# id
# 500836840       Emx1-IRES-Cre         177836119.0  500836840
# 307297141                None                 NaN  307297141
# 272821309       Cux2-IRES-Cre         177839022.0  272821309
# 512315551       Emx1-IRES-Cre         177836119.0  512315551
# 510581751       Tlx3-Cre_PL56         265180449.0  510581751
# ...                       ...                 ...        ...
# 596571282        Oxtr-T2A-Cre         301021674.0  596571282
# 638978767  Penk-IRES2-Cre-neo         298725927.0  638978767
# 503069254      Rbp4-Cre_KL100         177838435.0  503069254
# 263780729       Cux2-IRES-Cre         177839022.0  263780729
# 156545918     Ntsr1-Cre_GN220         177837713.0  156545918
#
#            primary_injection_structure
# id
# 500836840                          385
# 307297141                          385
# 272821309                          385
# 512315551                          385
# 510581751                          385
# ...                                ...
# 596571282                          385
# 638978767                          385
# 503069254                          385
# 263780729                          385
# 156545918                          385
#
# [285 rows x 16 columns]

# %% [markdown]
# If we decide to look at the projection densities of a given experiment, we can simply use the mcc to download that data, which will automatically be downloaded at our specified resolution.

# %%
projden, meta = mcc.get_projection_density(503069254)

# %%
print('Shape of projection density:',projden.shape)
print('Projection density data type:',projden.dtype)
print('Max value of projection density:',projden.max())
# Out:
# Shape of projection density: (528, 320, 456)
# Projection density data type: float64
# Max value of projection density: 1.0

# %% [markdown]
# According to the experiments data frame, this particular experiment has injection coordinates (8690,1440,3090) in microns. Our projden array is in 25 micron space, so we need to convert our coordinates.

# %%
8690/25
# Out:
# 347.6

# %%
plt.imshow(projden[348,:,:]) # indeces must be integers, so we round up from 347.6
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Saving Data
#
# The projection volume can also be written locally to a nrrd file, which can then be viewed by ITK-Snap.

# %%
import nrrd

# %%
nrrd.write('./projection_density_25_503069254.nrrd',projden)

# %% [markdown]
# ### Using Masks
#
# Using the masks we create from rsp, we can analyze parcel out the projection densities by annotated structure. For example, we can look at the sum projection density by structure using a loop. We'll have to account for left and right hemispheres, as the masks automatically include both.

# %%
print('Number of structures in structure graph:',len(sg.id))
# Out:
# Number of structures in structure graph: 839

# %% [markdown]
# There are 839 annotated structures, so this approach can be a little slow. If there are specific structures of interest, it may make more sense to simply sample those. For example, we can look at the projections in the Thalamus and all its substructures.
#
# To find the Thalamus's ID, we can use the structure graph.

# %%
sg[sg.name == 'Thalamus']
# Out:
#     acronym  graph_id  graph_order   id      name         structure_id_path  \
# 410      TH         1          641  549  Thalamus  [997, 8, 343, 1129, 549]
#
#                                      structure_set_ids      rgb_triplet
# 410  [2, 112905828, 691663206, 12, 184527634, 11290...  [255, 112, 128]

# %% [markdown]
# We can also use the structre tree in rsp to find the IDs of all of its descendants (substructures).

# %%
print(rsp.structure_tree.descendant_ids([549])[0])
# Out:
# [549, 864, 637, 629, 685, 709, 718, 725, 733, 741, 563807435, 406, 414, 422, 609, 1044, 1008, 475, 1072, 1079, 1088, 170, 496345664, 496345668, 496345672, 856, 138, 218, 1020, 1029, 325, 560581551, 239, 255, 127, 1096, 1104, 64, 1120, 1113, 155, 444, 59, 362, 366, 1077, 571, 149, 15, 181, 560581559, 51, 189, 599, 907, 575, 930, 560581563, 262, 1014, 27, 563807439, 178, 321, 958, 483, 186]

# %% [markdown]
# IDs are hard to make sense of, so we can map these back to their acronyms.

# %%
id_acronym_map = rsp.structure_tree.get_id_acronym_map() # Dictionary returns IDs given acronyms
acronym_id_map = {v:k for k,v in id_acronym_map.items()} # Flip key:value pairs to get dictionary for acronyms given IDs

# %%
print(list(map(acronym_id_map.get,rsp.structure_tree.descendant_ids([549])[0])))
# Out:
# ['TH', 'DORsm', 'VENT', 'VAL', 'VM', 'VP', 'VPL', 'VPLpc', 'VPM', 'VPMpc', 'PoT', 'SPF', 'SPFm', 'SPFp', 'SPA', 'PP', 'GENd', 'MG', 'MGd', 'MGv', 'MGm', 'LGd', 'LGd-sh', 'LGd-co', 'LGd-ip', 'DORpm', 'LAT', 'LP', 'PO', 'POL', 'SGN', 'Eth', 'ATN', 'AV', 'AM', 'AMd', 'AMv', 'AD', 'IAM', 'IAD', 'LD', 'MED', 'IMD', 'MD', 'SMT', 'PR', 'MTN', 'PVT', 'PT', 'RE', 'Xi', 'ILM', 'RH', 'CM', 'PCN', 'CL', 'PF', 'PIL', 'RT', 'GENv', 'IGL', 'IntG', 'LGv', 'SubG', 'EPI', 'MH', 'LH']

# %% [markdown]
# We can now sample our data by thalamic structure and hemisphere. We'll use a hemisphere id of 1 for the left hemisphere and 2 for the right. For the sum of signal in both hemispheres, we'll use a hemisphere id of 3.

# %%
sum_projden = []
for ID in rsp.structure_tree.descendant_ids([549])[0]:
    mask = rsp.make_structure_mask([ID])
    
    # left hemisphere
    left = projden[:,:,:228][mask[:,:,:228].nonzero()].sum()
    sum_projden.append({'id':ID, 'acronym':acronym_id_map[ID], 'hemisphere':1, 'sum_projection_density':left})
    
    # right hemisphere
    right = projden[:,:,228:][mask[:,:,228:].nonzero()].sum()
    sum_projden.append({'id':ID, 'acronym':acronym_id_map[ID], 'hemisphere':2, 'sum_projection_density':right})
    
    # both hemispheres
    sum_projden.append({'id':ID, 'acronym':acronym_id_map[ID], 'hemisphere':3, 'sum_projection_density':left+right})

# %%
df = pd.DataFrame(sum_projden)

# %%
df.head(10)
# Out:
#     id acronym  hemisphere  sum_projection_density
# 0  549      TH           1             6063.697628
# 1  549      TH           2                1.001049
# 2  549      TH           3             6064.698678
# 3  864   DORsm           1              981.310728
# 4  864   DORsm           2                0.065949
# 5  864   DORsm           3              981.376677
# 6  637    VENT           1              102.122931
# 7  637    VENT           2                0.009222
# 8  637    VENT           3              102.132154
# 9  629     VAL           1               10.000471

# %% [markdown]
# ### Accessing Experiments Structure Unionizes
#
# For connectivity data published through the AllenSDK, this has already been done and can be accessed using the mcc.

# %%
struct_union = mcc.get_experiment_structure_unionizes(503069254)

# %%
struct_union
# Out:
#       hemisphere_id         id  is_injection  max_voxel_density  max_voxel_x  \
# 0                 1  640637112         False           0.000000            0
# 1                 1  640636654         False           0.294172         2870
# 2                 3  640638251         False           0.106035         6280
# 3                 2  640635776         False           0.276934         8730
# 4                 2  640635309         False           0.001005         5790
# ...             ...        ...           ...                ...          ...
# 2547              1  640636867         False           0.027134         3560
# 2548              3  640638683         False           0.303791         6030
# 2549              1  640636605         False           0.117985         6550
# 2550              1  640636786         False           0.013185         7750
# 2551              2  640636201         False           0.000000            0
#
#       max_voxel_y  max_voxel_z  normalized_projection_volume  \
# 0               0            0                  0.000000e+00
# 1            4100         4850                  1.317984e-02
# 2             870         3070                  4.496597e-04
# 3            1030         6590                  3.117128e-03
# 4            6890         7820                  1.061473e-07
# ...           ...          ...                           ...
# 2547         3970         4770                  9.316448e-06
# 2548         1510         4990                  1.895807e-02
# 2549         1880         3520                  5.973397e-05
# 2550         4520         3970                  1.908338e-06
# 2551            0            0                  0.000000e+00
#
#       projection_density  projection_energy  projection_intensity  \
# 0           0.000000e+00           0.000000              0.000000
# 1           4.414019e-03           5.769497           1307.084961
# 2           1.744343e-04           0.123628            708.738327
# 3           2.394871e-04           0.290693           1213.813599
# 4           9.152569e-08           0.000055            603.535583
# ...                  ...                ...                   ...
# 2547        1.247779e-04           0.130877           1048.881348
# 2548        1.749223e-03           2.019338           1154.420060
# 2549        1.051872e-04           0.069200            657.877747
# 2550        1.022085e-06           0.000583            570.256653
# 2551        0.000000e+00           0.000000              0.000000
#
#       projection_volume  experiment_id  structure_id  sum_pixel_intensity  \
# 0          0.000000e+00      503069254           307         4.680124e+10
# 1          9.370700e-04      503069254           969         6.882283e+10
# 2          3.197025e-05      503069254     182305693         5.351576e+10
# 3          2.216240e-04      503069254           687         3.518189e+11
# 4          7.546941e-09      503069254           268         3.374464e+10
# ...                 ...            ...           ...                  ...
# 2547       6.623879e-07      503069254           680         7.519174e+08
# 2548       1.347896e-03      503069254           919         2.174851e+11
# 2549       4.247011e-06      503069254          1026         7.880844e+09
# 2550       1.356805e-07      503069254           804         2.643094e+10
# 2551       0.000000e+00      503069254          1023         1.273852e+11
#
#        sum_pixels  sum_projection_pixel_intensity  sum_projection_pixels  \
# 0     239999392.0                    0.000000e+00           0.000000e+00
# 1     173301296.0                    9.998613e+08           7.649551e+05
# 2     149616000.0                    1.849677e+07           2.609816e+04
# 3     755437504.0                    2.196002e+08           1.809175e+05
# 4      67311904.0                    3.718243e+03           6.160769e+00
# ...           ...                             ...                    ...
# 2547    4333500.0                    5.671562e+05           5.407249e+02
# 2548  629035200.0                    1.270235e+09           1.100323e+06
# 2549   32959800.0                    2.280828e+06           3.466948e+03
# 2550  108366304.0                    6.316137e+04           1.107596e+02
# 2551  272100608.0                    0.000000e+00           0.000000e+00
#
#         volume
# 0     0.293999
# 1     0.212294
# 2     0.183280
# 3     0.925411
# 4     0.082457
# ...        ...
# 2547  0.005309
# 2548  0.770568
# 2549  0.040376
# 2550  0.132749
# 2551  0.333323
#
# [2552 rows x 19 columns]

# %% [markdown]
# ## Structure Sets
#
# While there are 839 unique annotations in CCFv3, these annotations represent structures at different levels of ontology. Structure sets provide a way to access structures at a given level of ontology. For example, 12 high-level structures have been grouped together in a "coarse" structures set and 316 mid-level structures in a "summary" structures set. These sets of structures can be accessed through their structure_set_ids. To find the available structure sets, the OntologiesApi is needed.

# %%
from allensdk.api.queries.ontologies_api import OntologiesApi

# %%
oapi = OntologiesApi()

# %%
structure_sets = pd.DataFrame(oapi.get_structure_sets())

# %% [markdown]
# ### Coarse Structure Set

# %%
structure_sets[structure_sets.name.map(lambda x:'coarse' in x.lower())]
# Out:
#                                           description         id  \
# 3   List of structures representing a coarse level...          8
# 32  List of structures representing a coarse level...         11
# 36  List of structures used for the Developing Mou...  183237650
# 40  List of structures representing a coarse level...          4
# 46  List of structures representing a coarse level...          2
#
#                          name
# 3                NHP - Coarse
# 32  Developing Human - Coarse
# 36  Developing Mouse - Coarse
# 40             Human - Coarse
# 46             Mouse - Coarse

# %%
coarse_structures = pd.DataFrame(rsp.structure_tree.get_structures_by_set_id([2]))

# %%
coarse_structures
# Out:
#       acronym  graph_id  graph_order    id                   name  \
# 0   Isocortex         1            5   315              Isocortex
# 1         OLF         1          379   698        Olfactory areas
# 2         HPF         1          454  1089  Hippocampal formation
# 3       CTXsp         1          555   703      Cortical subplate
# 4         STR         1          571   477               Striatum
# 5         PAL         1          608   803               Pallidum
# 6          TH         1          641   549               Thalamus
# 7          HY         1          715  1097           Hypothalamus
# 8          MB         1          806   313               Midbrain
# 9           P         1          883   771                   Pons
# 10         MY         1          935   354                Medulla
# 11         CB         1         1014   512             Cerebellum
#
#                 structure_id_path  \
# 0    [997, 8, 567, 688, 695, 315]
# 1    [997, 8, 567, 688, 695, 698]
# 2   [997, 8, 567, 688, 695, 1089]
# 3         [997, 8, 567, 688, 703]
# 4         [997, 8, 567, 623, 477]
# 5         [997, 8, 567, 623, 803]
# 6        [997, 8, 343, 1129, 549]
# 7       [997, 8, 343, 1129, 1097]
# 8              [997, 8, 343, 313]
# 9        [997, 8, 343, 1065, 771]
# 10       [997, 8, 343, 1065, 354]
# 11                  [997, 8, 512]
#
#                                     structure_set_ids      rgb_triplet
# 0   [2, 112905828, 691663206, 12, 184527634, 11290...  [112, 255, 113]
# 1   [2, 3, 112905828, 691663206, 12, 184527634, 11...  [154, 210, 189]
# 2   [2, 112905828, 691663206, 12, 184527634, 11290...   [126, 208, 75]
# 3   [2, 3, 112905828, 691663206, 12, 184527634, 68...  [138, 218, 135]
# 4   [2, 112905828, 691663206, 12, 184527634, 11290...  [152, 214, 249]
# 5   [2, 112905828, 691663206, 12, 184527634, 11290...  [133, 153, 204]
# 6   [2, 112905828, 691663206, 12, 184527634, 11290...  [255, 112, 128]
# 7   [2, 112905828, 691663206, 12, 184527634, 11290...    [230, 68, 56]
# 8   [2, 112905828, 691663206, 12, 184527634, 11290...  [255, 100, 255]
# 9   [2, 112905828, 691663206, 12, 184527634, 11290...  [255, 155, 136]
# 10  [2, 112905828, 691663206, 12, 184527634, 11290...  [255, 155, 205]
# 11  [2, 112905828, 691663206, 12, 184527634, 11290...  [240, 240, 128]

# %% [markdown]
# ### Summary Structure Set

# %%
structure_sets[structure_sets.name.map(lambda x:'summary' in x.lower())]
# Out:
#                                           description         id  \
# 13      List of structures used for the HBA gene page  147814064
# 14  Structures representing subdivisions of the mo...  687527945
# 21  Curated list of non-overlapping substructures ...  167587189
# 30  List of structures used for the Developing Hum...  157025860
#
#                               name
# 13                 Human - Summary
# 14    Mouse Connectivity - Summary
# 21      Brain – Summary Structures
# 30  Developing Human - LCM Summary

# %%
summary_structures = pd.DataFrame(rsp.structure_tree.get_structures_by_set_id([167587189]))

# %%
summary_structures
# Out:
#           acronym  graph_id  graph_order         id  \
# 0             FRP         1            6        184
# 1             MOp         1           18        985
# 2             MOs         1           24        993
# 3           SSp-n         1           44        353
# 4         SSp-bfd         1           51        329
# ..            ...       ...          ...        ...
# 311            FN         1         1097        989
# 312            IP         1         1098         91
# 313            DN         1         1099        846
# 314          VeCB         1         1100  589508455
# 315  fiber tracts         1         1101       1009
#
#                                          name  \
# 0               Frontal pole, cerebral cortex
# 1                          Primary motor area
# 2                        Secondary motor area
# 3            Primary somatosensory area, nose
# 4    Primary somatosensory area, barrel field
# ..                                        ...
# 311                         Fastigial nucleus
# 312                        Interposed nucleus
# 313                           Dentate nucleus
# 314               Vestibulocerebellar nucleus
# 315                              fiber tracts
#
#                                structure_id_path  \
# 0              [997, 8, 567, 688, 695, 315, 184]
# 1         [997, 8, 567, 688, 695, 315, 500, 985]
# 2         [997, 8, 567, 688, 695, 315, 500, 993]
# 3    [997, 8, 567, 688, 695, 315, 453, 322, 353]
# 4    [997, 8, 567, 688, 695, 315, 453, 322, 329]
# ..                                           ...
# 311                      [997, 8, 512, 519, 989]
# 312                       [997, 8, 512, 519, 91]
# 313                      [997, 8, 512, 519, 846]
# 314                [997, 8, 512, 519, 589508455]
# 315                                  [997, 1009]
#
#                                      structure_set_ids      rgb_triplet
# 0    [3, 112905828, 688152357, 691663206, 687527945...    [38, 143, 69]
# 1    [112905828, 688152357, 691663206, 687527945, 1...    [31, 157, 90]
# 2    [112905828, 688152357, 691663206, 687527945, 1...    [31, 157, 90]
# 3    [112905828, 688152357, 691663206, 687527945, 1...   [24, 128, 100]
# 4    [112905828, 688152357, 691663206, 687527945, 1...   [24, 128, 100]
# ..                                                 ...              ...
# 311  [112905828, 691663206, 687527945, 12, 68815236...  [255, 253, 188]
# 312  [112905828, 691663206, 687527945, 12, 68815236...  [255, 253, 188]
# 313  [112905828, 691663206, 687527945, 12, 68815236...  [255, 253, 188]
# 314  [112905828, 691663206, 688152368, 184527634, 1...  [255, 253, 188]
# 315       [687527945, 184527634, 167587189, 691663206]  [204, 204, 204]
#
# [316 rows x 8 columns]

# %% [markdown]
# ## Sample Analysis: Projection Density
#
# As an example, we can now view the projection density across coarse-level structures for all connectivity experiments with primary injection in MOp.
#
# We have our coarse_structure_ids:

# %%
coarse_structure_ids = coarse_structures.id.values

# %%
coarse_structure_ids
# Out:
# array([ 315,  698, 1089,  703,  477,  803,  549, 1097,  313,  771,  354,
#         512], dtype=int64)

# %% [markdown]
# From our experiments data frame, we can get experiment ids corresponding to MOp experiments.

# %%
MOp_experiments = exp[exp.structure_abbrev == 'MOp'].id.values

# %% [markdown]
# Using the mcc, we can get structure unionizes for those experiments in the coarse structures.

# %%
MOp_exp_unionizes = mcc.get_structure_unionizes(MOp_experiments,structure_ids=coarse_structure_ids,hemisphere_ids=[1,2])

# %% [markdown]
# For each experiment, we can identify the injection hemisphere.

# %%
MOp_exp_unionizes[MOp_exp_unionizes.is_injection][['experiment_id','hemisphere_id']]
# Out:
#      experiment_id  hemisphere_id
# 3        272697944              2
# 32       180720175              2
# 55       100141563              2
# 91       288169135              2
# 108      127084296              2
# 148      157909001              2
# 154      126909424              2
# 177      182616478              2
# 221      298325807              2
# 235      166082842              2
# 255      310194040              2
# 256      310194040              2
# 283      597007858              2
# 324      179641666              2
# 336      177893658              2
# 375      156786234              2
# 387      183103805              2
# 404      298273313              2
# 440      287461719              2
# 467      477836675              2
# 478      159651060              2
# 505      606250170              2
# 543      166461193              2
# 557      168229113              2
# 582      591612976              2
# 625      584903636              2
# 640      297711339              2
# 663      100141780              2
# 687      179640955              2
# 711      100141273              2
# 728      512130198              2
# 755      277957908              2

# %% [markdown]
# If we are interested in ipsilateral projection densities, we can sample the unionizes results to include only non-injection results in the right hemisphere. Then we pivot the table to find the projection density in each coarse-level structure for each experiment.

# %%
MOp_union_subsample = MOp_exp_unionizes[(MOp_exp_unionizes.hemisphere_id == 2)&(~MOp_exp_unionizes.is_injection)]
projection_density_table = MOp_union_subsample.pivot(index='experiment_id',columns='structure_id',values='projection_density')

# %%
projection_density_table
# Out:
# structure_id           313       315           354       477           512   \
# experiment_id
# 100141273      1.349080e-02  0.030909  2.070341e-03  0.027687  6.289388e-05
# 100141563      6.412045e-03  0.028486  7.177390e-04  0.026409  1.671713e-05
# 100141780      4.573775e-02  0.101302  1.970974e-02  0.122114  6.949410e-05
# 126909424      1.640693e-02  0.054693  5.434712e-03  0.076684  3.235712e-05
# 127084296      4.711831e-02  0.073112  2.049558e-02  0.103921  1.743017e-04
# 156786234      5.093987e-03  0.006292  2.800595e-03  0.009925  7.188454e-05
# 157909001      6.754403e-06  0.000529  2.677828e-05  0.000831  4.445020e-06
# 159651060      1.481436e-05  0.000519  1.408177e-04  0.000606  1.317454e-05
# 166082842      2.985407e-02  0.032732  9.843254e-03  0.047774  1.157885e-04
# 166461193      9.419812e-04  0.000921  1.605177e-03  0.000922  1.688427e-04
# 168229113      3.364101e-03  0.002566  1.195694e-03  0.003553  3.389987e-05
# 177893658      2.477856e-05  0.015379  1.331861e-04  0.004551  8.139334e-05
# 179640955      1.231889e-05  0.000559  7.721384e-05  0.000274  1.125715e-06
# 179641666      9.416636e-04  0.002502  1.093743e-03  0.003299  7.738733e-05
# 180720175      7.786241e-02  0.083879  2.899762e-02  0.112213  3.570345e-04
# 182616478      1.120066e-04  0.016191  5.832381e-04  0.002329  3.163920e-03
# 183103805      7.697802e-07  0.000951  1.741761e-05  0.000016  4.585652e-09
# 272697944      8.680221e-03  0.017894  3.409594e-03  0.013769  1.547346e-05
# 277957908      8.643273e-03  0.006473  2.514679e-03  0.010595  4.552808e-05
# 287461719      7.228812e-05  0.000917  3.826557e-07  0.000497  3.228493e-07
# 288169135      4.209512e-02  0.061638  7.510867e-03  0.070216  7.703036e-06
# 297711339      1.019465e-02  0.005171  8.783135e-04  0.007869  2.468604e-06
# 298273313      1.373921e-02  0.011765  8.018618e-04  0.008001  1.017059e-05
# 298325807      4.572586e-03  0.003219  1.166197e-03  0.003887  1.868503e-06
# 310194040      2.438436e-05  0.001660  1.987619e-04  0.001312  2.687773e-05
# 477836675      1.488653e-05  0.005355  5.381717e-05  0.000941  1.223162e-05
# 512130198      6.521516e-03  0.003747  1.422075e-03  0.006583  1.920861e-07
# 584903636      2.393540e-02  0.045937  5.665288e-03  0.079462  3.943900e-06
# 591612976      4.168360e-05  0.015962  1.149326e-04  0.024349  5.789698e-05
# 597007858      5.380135e-03  0.001349  1.205654e-03  0.004541  5.884361e-06
# 606250170      7.513003e-03  0.002901  2.054396e-03  0.006003  2.193598e-05
#
# structure_id       549           698           703       771           803   \
# experiment_id
# 100141273      0.019292  7.185106e-05  1.481179e-04  0.011568  4.580986e-03
# 100141563      0.011719  3.050792e-05  1.803481e-04  0.004184  3.499042e-03
# 100141780      0.098057  3.104095e-04  1.998705e-03  0.028838  4.644044e-02
# 126909424      0.037715  2.101836e-04  5.271551e-04  0.012215  1.621536e-02
# 127084296      0.100418  5.658817e-04  1.726880e-03  0.044064  1.806637e-02
# 156786234      0.036757  9.202881e-05  5.829610e-05  0.005895  1.506559e-03
# 157909001      0.010497  4.233673e-06  0.000000e+00  0.000018  5.379419e-05
# 159651060      0.009899  2.659274e-05  6.424786e-08  0.000085  2.047610e-04
# 166082842      0.029015  4.366865e-04  1.030695e-03  0.025760  8.031786e-03
# 166461193      0.001445  2.355719e-04  5.147127e-06  0.001397  5.266798e-04
# 168229113      0.061464  4.114946e-05  1.759281e-06  0.002444  1.356901e-03
# 177893658      0.000009  1.023816e-04  1.412213e-05  0.000077  3.623345e-04
# 179640955      0.003006  7.728266e-05  1.921653e-06  0.000123  8.369677e-05
# 179641666      0.065473  5.640211e-05  3.775054e-06  0.001435  2.278953e-03
# 180720175      0.109487  1.698304e-03  7.925331e-03  0.083346  1.525468e-02
# 182616478      0.000633  3.463885e-04  2.566112e-05  0.000134  1.983854e-04
# 183103805      0.000031  2.946923e-08  0.000000e+00  0.000000  3.085066e-08
# 272697944      0.026702  6.713041e-06  1.883192e-04  0.003692  1.217659e-02
# 277957908      0.018767  4.503262e-05  4.250062e-06  0.008603  7.909742e-03
# 287461719      0.000330  3.828681e-05  1.736190e-08  0.000017  1.494159e-04
# 288169135      0.042669  1.464028e-03  3.702355e-03  0.022147  1.581693e-02
# 297711339      0.006415  3.701712e-05  2.591457e-06  0.004284  2.443915e-03
# 298273313      0.011529  1.894769e-04  3.762485e-05  0.005633  7.993895e-03
# 298325807      0.004952  7.970556e-05  1.008335e-05  0.003221  4.279387e-03
# 310194040      0.000176  3.225879e-05  2.433025e-05  0.000076  3.872835e-04
# 477836675      0.002241  1.802455e-05  1.631442e-05  0.000048  5.346219e-04
# 512130198      0.006189  2.200946e-05  7.318840e-06  0.005416  4.203804e-03
# 584903636      0.031177  1.863707e-04  8.279865e-04  0.011430  2.349467e-02
# 591612976      0.000016  7.691944e-05  6.425746e-04  0.000077  5.351253e-04
# 597007858      0.005272  4.890241e-05  7.697216e-06  0.003039  1.701985e-03
# 606250170      0.008066  5.721224e-05  3.026546e-06  0.006987  1.506591e-03
#
# structure_id           1089      1097
# experiment_id
# 100141273      7.184287e-05  0.007126
# 100141563      4.795431e-05  0.003935
# 100141780      3.999331e-04  0.020102
# 126909424      1.716700e-04  0.007089
# 127084296      5.657594e-04  0.022148
# 156786234      6.693332e-05  0.002492
# 157909001      5.354970e-06  0.000057
# 159651060      6.318669e-06  0.000081
# 166082842      6.089168e-04  0.015457
# 166461193      1.312405e-04  0.000443
# 168229113      2.798675e-05  0.001950
# 177893658      6.477659e-05  0.000039
# 179640955      1.835133e-05  0.000018
# 179641666      5.324807e-05  0.000486
# 180720175      2.484196e-03  0.045100
# 182616478      2.450975e-04  0.000264
# 183103805      5.989210e-08  0.000000
# 272697944      1.161329e-05  0.001038
# 277957908      5.898564e-05  0.004755
# 287461719      2.317520e-05  0.000016
# 288169135      9.293391e-04  0.024200
# 297711339      3.365363e-05  0.005471
# 298273313      7.980505e-05  0.006501
# 298325807      2.510574e-05  0.001781
# 310194040      2.290002e-05  0.000016
# 477836675      1.352345e-05  0.000020
# 512130198      1.003904e-04  0.003483
# 584903636      1.424482e-04  0.007572
# 591612976      1.464142e-04  0.000047
# 597007858      7.215167e-05  0.002659
# 606250170      1.302066e-04  0.004213

# %% [markdown]
# To view this as a heatmap, we get the axes of the table and convert the structure_ids to acronyms for legibility. We also need the matrix of the values in the table.

# %%
structures = projection_density_table.columns.map(acronym_id_map)

# %%
experiments = projection_density_table.index

# %%
projection_density_matrix = projection_density_table.values

# %%
fig, ax = plt.subplots()
fig.set_size_inches(len(structures)/3,len(experiments)/3)

im = ax.imshow(projection_density_matrix)

ax.set_xticks(np.arange(len(structures)))
ax.set_yticks(np.arange(len(experiments)))

ax.set_xticklabels(structures, rotation=90)
ax.set_yticklabels(experiments)

ax.xaxis.tick_top()

fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# ## Download Section Images
#
# It is also important to be able to access and view the section images for a given experiment. This can be done through the ImageDownloadApi.

# %%
from allensdk.api.queries.image_download_api import ImageDownloadApi
from allensdk.core.mouse_connectivity_cache import MouseConnectivityApi
import os

# %% [markdown]
# For a given experiment, we can access all its sections through the experiment ID.

# %%
ID = 503069254

# %% [markdown]
# We instantiate the ImageDownloadApi to download images and use the MouseConnectivityApi to access relevant data for those images, such as equalization parameters.

# %%
mca = MouseConnectivityApi()
ida = ImageDownloadApi()

# %% [markdown]
# For a given experiment, each section has a unique section_id, which we can access from its sections frame. Here, we see that this brain has been sectioned into 140 individual sections.

# %%
sections_frame = pd.DataFrame(ida.section_image_query(ID))

# %%
sections_frame
# Out:
#      annotated  axes  bits_per_component  data_set_id expression  \
# 0        False  None                  16    503069254       None
# 1        False  None                  16    503069254       None
# 2        False  None                  16    503069254       None
# 3        False  None                  16    503069254       None
# 4        False  None                  16    503069254       None
# ..         ...   ...                 ...          ...        ...
# 135      False  None                  16    503069254       None
# 136      False  None                  16    503069254       None
# 137      False  None                  16    503069254       None
# 138      False  None                  16    503069254       None
# 139      False  None                  16    503069254       None
#
#     expression_path  failed  height         id  image_height  ...  \
# 0              None   False   29998  503069410         30000  ...
# 1              None   False   29998  503069825         30000  ...
# 2              None   False   29998  503069770         30000  ...
# 3              None   False   29998  503070298         30000  ...
# 4              None   False   29998  503070413         30000  ...
# ..              ...     ...     ...        ...           ...  ...
# 135            None   False   29998  503069758         30000  ...
# 136            None   False   29998  503069762         30000  ...
# 137            None   False   29998  503070467         30000  ...
# 138            None   False   29998  503069603         30000  ...
# 139            None   False   29998  503070017         30000  ...
#
#                                                   path  projection_function  \
# 0    /external/connectivity/prod426/0500336532-0122...                 None
# 1    /external/connectivity/prod426/0500336532-0082...                 None
# 2    /external/connectivity/prod426/0500336532-0087...                 None
# 3    /external/connectivity/prod426/0500336532-0036...                 None
# 4    /external/connectivity/prod426/0500336532-0027...                 None
# ..                                                 ...                  ...
# 135  /external/connectivity/prod426/0500336532-0089...                 None
# 136  /external/connectivity/prod426/0500336532-0088...                 None
# 137  /external/connectivity/prod426/0500336532-0021...                 None
# 138  /external/connectivity/prod426/0500336532-0101...                 None
# 139  /external/connectivity/prod426/0500336532-0061...                 None
#
#     resolution section_number  specimen_id structure_id tier_count  width  x  \
# 0         0.35            123         None         None          9  39998  1
# 1         0.35             83         None         None          9  39998  1
# 2         0.35             88         None         None          9  39998  1
# 3         0.35             37         None         None          9  39998  1
# 4         0.35             28         None         None          9  39998  1
# ..         ...            ...          ...          ...        ...    ... ..
# 135       0.35             90         None         None          9  39998  1
# 136       0.35             89         None         None          9  39998  1
# 137       0.35             22         None         None          9  39998  1
# 138       0.35            102         None         None          9  39998  1
# 139       0.35             62         None         None          9  39998  1
#
#      y
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# ..  ..
# 135  1
# 136  1
# 137  1
# 138  1
# 139  1
#
# [140 rows x 26 columns]

# %% [markdown]
# We are interested in the section_id corresponding to each section, so we extract those values from the data frame.

# %%
section_ids = sections_frame[['section_number','id']].values

# %%
print(section_ids)
# Out:
# [[      123 503069410]
#  [       83 503069825]
#  [       88 503069770]
#  [       37 503070298]
#  [       28 503070413]
#  [       49 503070144]
#  [       48 503070152]
#  [        6 503070614]
#  [      113 503069503]
#  [       51 503070136]
#  [       35 503070318]
#  [      130 503069350]
#  [       91 503069754]
#  [       47 503070162]
#  [       67 503069973]
#  [       24 503070455]
#  [       98 503069673]
#  [       95 503069700]
#  [       46 503070172]
#  [        9 503070592]
#  [       45 503070217]
#  [       63 503070006]
#  [       53 503070128]
#  [      121 503069429]
#  [       41 503070282]
#  [       13 503070566]
#  [      139 503069291]
#  [       12 503070570]
#  [      140 503069283]
#  [       40 503070286]
#  [      135 503069318]
#  [      134 503069323]
#  [       33 503070343]
#  [       16 503070543]
#  [       86 503069804]
#  [      116 503069467]
#  [       31 503070379]
#  [      108 503069559]
#  [       43 503070249]
#  [      119 503069447]
#  [       60 503070033]
#  [       66 503069981]
#  [      115 503069475]
#  [       44 503070236]
#  [       55 503070105]
#  [      133 503069329]
#  [       74 503069877]
#  [       59 503070055]
#  [        8 503070599]
#  [      131 503069342]
#  [      129 503069358]
#  [       93 503069734]
#  [      106 503069584]
#  [       54 503070118]
#  [      125 503069399]
#  [      110 503069529]
#  [      118 503069455]
#  [      112 503069507]
#  [        4 503070638]
#  [      120 503069439]
#  [       80 503069848]
#  [      126 503069395]
#  [       87 503069774]
#  [       71 503069944]
#  [       96 503069686]
#  [       17 503070539]
#  [      124 503069403]
#  [      122 503069419]
#  [       15 503070548]
#  [       19 503070479]
#  [       56 503070093]
#  [      100 503069664]
#  [        3 503070646]
#  [       25 503070445]
#  [      114 503069479]
#  [       58 503070067]
#  [       97 503069677]
#  [      141 503069279]
#  [       20 503070475]
#  [       76 503069869]
#  [       34 503070331]
#  [      137 503069303]
#  [       99 503069669]
#  [       26 503070433]
#  [       21 503070471]
#  [       81 503069840]
#  [       57 503070080]
#  [       50 503070140]
#  [      117 503069463]
#  [      111 503069515]
#  [       27 503070422]
#  [      103 503069596]
#  [       79 503069854]
#  [       77 503069865]
#  [        2 503070655]
#  [       52 503070132]
#  [      109 503069543]
#  [      105 503069588]
#  [       69 503069960]
#  [       39 503070290]
#  [       70 503069948]
#  [      107 503069571]
#  [       10 503070583]
#  [      127 503069391]
#  [       42 503070264]
#  [       85 503069812]
#  [       68 503069968]
#  [      138 503069299]
#  [       23 503070463]
#  [       14 503070552]
#  [      104 503069592]
#  [       11 503070575]
#  [       84 503069818]
#  [       65 503069987]
#  [       61 503070023]
#  [      101 503069614]
#  [      136 503069311]
#  [       73 503069881]
#  [       29 503070401]
#  [       38 503070294]
#  [        5 503070621]
#  [       94 503069717]
#  [       32 503070355]
#  [       72 503069940]
#  [      132 503069335]
#  [      128 503069365]
#  [       82 503069832]
#  [       18 503070483]
#  [       64 503069997]
#  [       36 503070306]
#  [       30 503070389]
#  [        7 503070606]
#  [       78 503069861]
#  [       75 503069873]
#  [       92 503069749]
#  [       90 503069758]
#  [       89 503069762]
#  [       22 503070467]
#  [      102 503069603]
#  [       62 503070017]]

# %% [markdown]
# We can access the equalization parameters from the experiment details, which we get from the MouseConnectivityApi (mca). This lets us get equalization ranges for each channel, to pass to the image downloader.

# %%
details = mca.get_experiment_detail(ID)
equalization_params = pd.DataFrame(details).T.loc['equalization'].values[0]
equalization_ranges = [equalization_params['red_lower'],equalization_params['red_upper'],equalization_params['green_lower'],
     equalization_params['green_upper'],equalization_params['blue_lower'],equalization_params['blue_upper']]

# %%
equalization_ranges
# Out:
# [0, 990, 0, 2962, 0, 4095]

# %% [markdown]
# We can now download the images. It can be convenient to put them all in a directory for that particular experiment. Then we download each individual section. In this case, we are downsampling the image by a factor of 4.

# %%
if not os.path.exists('./{0}/sections'.format(ID)):
    os.mkdir('./{0}/sections'.format(ID))
    
for section_number, section_id in section_ids:
    ida.download_image(section_id,downsample=4,range=equalization_ranges,
                       file_path='./{0}/sections/{1}.jpg'.format(ID,section_number))
# Out:
# 2021-03-10 10:40:13,996 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069410?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:14,644 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069825?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:15,371 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069770?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:16,165 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070298?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:17,059 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070413?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:17,895 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070144?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:18,694 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070152?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:19,399 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070614?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:20,015 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069503?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:20,889 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070136?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:21,739 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070318?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:22,521 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069350?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:23,318 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069754?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:24,126 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070162?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:24,868 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069973?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:25,599 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070455?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:26,437 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069673?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:27,260 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069700?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:28,079 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070172?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:28,899 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070592?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:29,618 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070217?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:30,442 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070006?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:31,408 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070128?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:32,112 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069429?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:32,773 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070282?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:33,506 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070566?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:34,499 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069291?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:35,148 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070570?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:35,956 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069283?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:36,501 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070286?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:37,194 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069318?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:37,749 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069323?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:38,326 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070343?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:39,175 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070543?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:40,115 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069804?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:40,863 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069467?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:41,573 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070379?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:42,311 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069559?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:43,135 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070249?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:43,975 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069447?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:44,670 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070033?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:45,518 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069981?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:46,330 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069475?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:47,067 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070236?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:47,736 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070105?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:48,486 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069329?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:49,077 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069877?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:49,882 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070055?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:50,681 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070599?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:51,356 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069342?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:51,962 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069358?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:52,720 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069734?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:53,635 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069584?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:54,373 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070118?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:55,077 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069399?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:55,772 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069529?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:56,496 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069455?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:57,191 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069507?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:58,019 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070638?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:58,618 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069439?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:40:59,313 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069848?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:00,171 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069395?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:01,170 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069774?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:01,977 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069944?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:03,055 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069686?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:03,893 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070539?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:04,746 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069403?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:05,456 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069419?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:06,123 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070548?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:07,163 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070479?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:07,958 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070093?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:08,712 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069664?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:09,760 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070646?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:10,756 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070445?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:11,693 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069479?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:12,402 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070067?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:13,409 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069677?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:14,231 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069279?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:14,791 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070475?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:15,681 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069869?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:16,557 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070331?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:17,479 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069303?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:18,060 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069669?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:18,897 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070433?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:19,782 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070471?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:20,539 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069840?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:21,399 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070080?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:22,161 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070140?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:23,021 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069463?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:23,723 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069515?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:24,431 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070422?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:25,218 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069596?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:26,006 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069854?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:26,758 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069865?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:27,538 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070655?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:28,112 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070132?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:28,846 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069543?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:29,591 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069588?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:30,413 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069960?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:31,288 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070290?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:32,057 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069948?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:32,902 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069571?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:33,694 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070583?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:34,456 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069391?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:35,244 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070264?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:35,889 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069812?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:36,583 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069968?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:37,368 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069299?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:38,151 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070463?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:38,958 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070552?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:39,820 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069592?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:40,683 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070575?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:41,469 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069818?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:42,165 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069987?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:42,914 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070023?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:43,741 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069614?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:44,489 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069311?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:45,058 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069881?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:45,928 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070401?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:46,726 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070294?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:47,569 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070621?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:48,312 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069717?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:49,163 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070355?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:51,015 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069940?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:51,913 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069335?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:52,546 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069365?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:53,265 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069832?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:54,060 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070483?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:54,862 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069997?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:55,788 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070306?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:56,800 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070389?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:57,586 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070606?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:58,244 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069861?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:59,122 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069873?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:41:59,875 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069749?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:42:00,683 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069758?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:42:01,481 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069762?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:42:02,204 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070467?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:42:03,098 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503069603?downsample=4&range=0,990,0,2962,0,4095
# 2021-03-10 10:42:04,064 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/image_download/503070017?downsample=4&range=0,990,0,2962,0,4095
